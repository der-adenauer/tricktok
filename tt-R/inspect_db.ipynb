# %%
# Datenbankinhalt in einen Pandas-DataFrame laden

import pandas as pd
import sqlite3
def db_to_dataframe(db_name="filtered_tiktok_media_metadata.db"):
    conn = sqlite3.connect(db_name)
    query = "SELECT * FROM media_metadata"
    try:
        df = pd.read_sql_query(query, conn)
        return df
    except sqlite3.Error as e:
        print(f"Fehler: {e}")
        return None
    finally:
        conn.close()

df = db_to_dataframe()

df
# Out:
#                         id                                                url  \
# 0      7468773814415985942  https://www.tiktok.com/@alice_weidel_fan/video...
# 1      7468732757892533527  https://www.tiktok.com/@alice_weidel_fan/video...
# 2      7468530461313142038  https://www.tiktok.com/@alice_weidel_fan/video...
# 3      7468400204899798294  https://www.tiktok.com/@alice_weidel_fan/video...
# 4      7468303111166119190  https://www.tiktok.com/@alice_weidel_fan/video...
# ...                    ...                                                ...
# 98811  7469669305920146710  https://www.tiktok.com/@andreazuercherafd/vide...
# 98812  7469361691990510870  https://www.tiktok.com/@andreazuercherafd/vide...
# 98813  7469534369804340502  https://www.tiktok.com/@klaus__afd/video/74695...
# 98814  7469518720281349398  https://www.tiktok.com/@klaus__afd/video/74695...
# 98815  7469515817592409366  https://www.tiktok.com/@klaus__afd/video/74695...
#
#                                                    title  \
# 0      Zusammen gegen alle 🫶 #afd #demo #hamburg #pol...
# 1              #afd #demo #aliceweidel #antifa #politik
# 2      Wir versammeln uns 🫶 #afd #demo #hamburg #berl...
# 3             #afd #demo #aliceweidel #hamburg #politik
# 4      Hamburg gegen Rechts #afd #demo #politik #deut...
# ...                                                  ...
# 98811  Aus aktuellem Anlass! #andreazuercher #alterna...
# 98812  Es war großartig, die Antifa durfte natürlich ...
# 98813                                           #CapCut
# 98814  09.02.2025 Neue Kampagne gegen die AfD und das...
# 98815  09.02.2025 Auf1 exklusiv Kampagne gegen die Af...
#
#                                              description  duration  \
# 0      Zusammen gegen alle 🫶 #afd #demo #hamburg #pol...      60.0
# 1              #afd #demo #aliceweidel #antifa #politik       61.0
# 2      Wir versammeln uns 🫶 #afd #demo #hamburg #berl...      61.0
# 3             #afd #demo #aliceweidel #hamburg #politik       66.0
# 4      Hamburg gegen Rechts #afd #demo #politik #deut...      60.0
# ...                                                  ...       ...
# 98811  Aus aktuellem Anlass! #andreazuercher #alterna...       6.0
# 98812  Es war großartig, die Antifa durfte natürlich ...      65.0
# 98813                                           #CapCut        5.0
# 98814  09.02.2025 Neue Kampagne gegen die AfD und das...      34.0
# 98815  09.02.2025 Auf1 exklusiv Kampagne gegen die Af...      21.0
#
#        view_count  like_count  repost_count  comment_count           uploader  \
# 0             338          71             1             25   alice_weidel_fan
# 1            9193        1372            19            363   alice_weidel_fan
# 2          147400       17400           592           1638   alice_weidel_fan
# 3           31000        4393            36            954   alice_weidel_fan
# 4           13600        1697            24            354   alice_weidel_fan
# ...           ...         ...           ...            ...                ...
# 98811       11600        2044             8            449  andreazuercherafd
# 98812       14500        1670            25            342  andreazuercherafd
# 98813         302           4             0              0         klaus__afd
# 98814         365          45             3              1         klaus__afd
# 98815        1661         145            29             28         klaus__afd
#
#                uploader_id               channel  \
# 0      7464621854616093718   Politik und Protest
# 1      7464621854616093718   Politik und Protest
# 2      7464621854616093718   Politik und Protest
# 3      7464621854616093718   Politik und Protest
# 4      7464621854616093718   Politik und Protest
# ...                    ...                   ...
# 98811  6666441368116723717  Andrea Zürcher AfD 💙
# 98812  6666441368116723717  Andrea Zürcher AfD 💙
# 98813  7312935479468704801     Klaus_AfD_München
# 98814  7312935479468704801     Klaus_AfD_München
# 98815  7312935479468704801     Klaus_AfD_München
#
#                                               channel_id  \
# 0      MS4wLjABAAAAq1VhyNiIDoeDFoDC1NpcZs4CZyWggOs2o4...
# 1      MS4wLjABAAAAq1VhyNiIDoeDFoDC1NpcZs4CZyWggOs2o4...
# 2      MS4wLjABAAAAq1VhyNiIDoeDFoDC1NpcZs4CZyWggOs2o4...
# 3      MS4wLjABAAAAq1VhyNiIDoeDFoDC1NpcZs4CZyWggOs2o4...
# 4      MS4wLjABAAAAq1VhyNiIDoeDFoDC1NpcZs4CZyWggOs2o4...
# ...                                                  ...
# 98811  MS4wLjABAAAAx18EgWma5KUkjy1jcbEPOBjVFEUNkUj967...
# 98812  MS4wLjABAAAAx18EgWma5KUkjy1jcbEPOBjVFEUNkUj967...
# 98813  MS4wLjABAAAA4b3FPTKroU-x4FSmiCX3QSDHr9KX1OPjVw...
# 98814  MS4wLjABAAAA4b3FPTKroU-x4FSmiCX3QSDHr9KX1OPjVw...
# 98815  MS4wLjABAAAA4b3FPTKroU-x4FSmiCX3QSDHr9KX1OPjVw...
#
#                                              channel_url          track  \
# 0      https://www.tiktok.com/@MS4wLjABAAAAq1VhyNiIDo...    Originalton
# 1      https://www.tiktok.com/@MS4wLjABAAAAq1VhyNiIDo...    Originalton
# 2      https://www.tiktok.com/@MS4wLjABAAAAq1VhyNiIDo...    Originalton
# 3      https://www.tiktok.com/@MS4wLjABAAAAq1VhyNiIDo...    Originalton
# 4      https://www.tiktok.com/@MS4wLjABAAAAq1VhyNiIDo...    Originalton
# ...                                                  ...            ...
# 98811  https://www.tiktok.com/@MS4wLjABAAAAx18EgWma5K...    Originalton
# 98812  https://www.tiktok.com/@MS4wLjABAAAAx18EgWma5K...    Originalton
# 98813  https://www.tiktok.com/@MS4wLjABAAAA4b3FPTKroU...    Originalton
# 98814  https://www.tiktok.com/@MS4wLjABAAAA4b3FPTKroU...    Originalton
# 98815  https://www.tiktok.com/@MS4wLjABAAAA4b3FPTKroU...  Breaking News
#
#                album               artists   timestamp extractor
# 0               None         𝖚𝖑𝖙𝖗𝖆𝖘 𝖉𝖞𝖓𝖆𝖒𝖔  1738959418      None
# 1               None         𝖚𝖑𝖙𝖗𝖆𝖘 𝖉𝖞𝖓𝖆𝖒𝖔  1738949860      None
# 2               None   Politik und Protest  1738902811      None
# 3               None   Politik und Protest  1738872431      None
# 4               None   Politik und Protest  1738849825      None
# ...              ...                   ...         ...       ...
# 98811           None  Andrea Zürcher AfD 💙  1739167931      None
# 98812           None       Carsten Lindner  1739096298      None
# 98813           None     Klaus_AfD_München  1739136502      None
# 98814           None     Klaus_AfD_München  1739132855      None
# 98815  Breaking News                   Dih  1739132179      None
#
# [98816 rows x 19 columns]

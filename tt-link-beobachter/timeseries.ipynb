# %%
import sqlite3
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Verbindung zur SQLite-Datenbank herstellen
conn = sqlite3.connect('tiktok_media_metadata.db')

# Daten aus der `media_time_series`-Tabelle in ein DataFrame laden
query = "SELECT * FROM media_time_series"
df = pd.read_sql_query(query, conn)

# Datenbankverbindung schließen
conn.close()

# %%
# Verbindung zur SQLite-Datenbank herstellen
conn = sqlite3.connect('tiktok_media_metadata.db')

# Daten aus der `media_time_series`-Tabelle in ein DataFrame laden
query = "SELECT * FROM media_metadata"
df2 = pd.read_sql_query(query, conn)

# Datenbankverbindung schließen
conn.close()

# %%
# Übersicht über die Datenstruktur
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 983963 entries, 0 to 983962
# Data columns (total 7 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   series_id      983963 non-null  int64
#  1   url            983963 non-null  object
#  2   view_count     983963 non-null  int64
#  3   like_count     983963 non-null  int64
#  4   repost_count   983963 non-null  int64
#  5   comment_count  983963 non-null  int64
#  6   recorded_at    983963 non-null  object
# dtypes: int64(5), object(2)
# memory usage: 52.5+ MB
# None

# %%
print(df2.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47561 entries, 0 to 47560
# Data columns (total 19 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             47561 non-null  object
#  1   url            47561 non-null  object
#  2   title          47561 non-null  object
#  3   description    47561 non-null  object
#  4   duration       47196 non-null  float64
#  5   view_count     47561 non-null  int64
#  6   like_count     47561 non-null  int64
#  7   repost_count   47561 non-null  int64
#  8   comment_count  47561 non-null  int64
#  9   uploader       47561 non-null  object
#  10  uploader_id    47561 non-null  object
#  11  channel        47561 non-null  object
#  12  channel_id     47561 non-null  object
#  13  channel_url    47561 non-null  object
#  14  track          47561 non-null  object
#  15  album          8435 non-null   object
#  16  artists        47561 non-null  object
# ...

# %%
df[100:20000]
# Out:
#        series_id                                                url  \
# 100          101  https://www.tiktok.com/@carolin_bachmann_mdb/v...
# 101          102  https://www.tiktok.com/@carolin_bachmann_mdb/v...
# 102          103  https://www.tiktok.com/@carolin_bachmann_mdb/v...
# 103          104  https://www.tiktok.com/@carolin_bachmann_mdb/v...
# 104          105  https://www.tiktok.com/@carolin_bachmann_mdb/v...
# ...          ...                                                ...
# 19995      19996  https://www.tiktok.com/@biene_afd_1989/video/7...
# 19996      19997  https://www.tiktok.com/@biene_afd_1989/video/7...
# 19997      19998  https://www.tiktok.com/@biene_afd_1989/video/7...
# 19998      19999  https://www.tiktok.com/@biene_afd_1989/video/7...
# 19999      20000  https://www.tiktok.com/@biene_afd_1989/video/7...
#
#        view_count  like_count  repost_count  comment_count  \
# 100         44000        3119           175            518
# ...

# %%
df2
# Out:
#                         id                                                url  \
# 0      7453041971486133536  https://www.tiktok.com/@gereonbollmann/video/7...
# 1      7446314527685201185  https://www.tiktok.com/@gereonbollmann/video/7...
# 2      7430740655854390560  https://www.tiktok.com/@gereonbollmann/video/7...
# 3      7429638543347076385  https://www.tiktok.com/@gereonbollmann/video/7...
# 4      7424819005254405408  https://www.tiktok.com/@gereonbollmann/video/7...
# ...                    ...                                                ...
# 47556  7464218206287236374  https://www.tiktok.com/@deutschland11afd/video...
# 47557  7464211887169801494  https://www.tiktok.com/@afd.frieden/video/7464...
# 47558  7464229027495136519  https://www.tiktok.com/@afd0426/video/74642290...
# 47559  7464232170798828821  https://www.tiktok.com/@ahmd.frdss/video/74642...
# 47560  7464216556864638229  https://www.tiktok.com/@ahmd.frdss/video/74642...
#
# ...

# %%
df.describe()
# Out:
#            series_id    view_count    like_count  repost_count  comment_count
# count  983963.000000  9.839630e+05  9.839630e+05  9.839630e+05  983963.000000
# mean   491982.000000  1.360211e+05  6.529974e+03  1.232955e+03     222.118648
# std    284045.795799  2.685570e+06  8.780075e+04  4.134863e+04    3004.992425
# min         1.000000  0.000000e+00  0.000000e+00  0.000000e+00       0.000000
# 25%    245991.500000  5.650000e+02  4.600000e+01  1.000000e+00       2.000000
# 50%    491982.000000  1.717000e+03  1.650000e+02  5.000000e+00      11.000000
# 75%    737972.500000  1.650000e+04  1.249000e+03  4.700000e+01      64.000000
# max    983963.000000  4.495000e+08  1.240000e+07  8.300000e+06  608600.000000

# %%
# Datumsspalte in den richtigen Datentyp umwandeln
df['recorded_at'] = pd.to_datetime(df['recorded_at'])

# Überprüfen, ob die Umwandlung erfolgreich war
print(df.dtypes)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 2
#       1 # Datumsspalte in den richtigen Datentyp umwandeln
# ----> 2 df['recorded_at'] = pd.to_datetime(df['recorded_at'])
#       4 # Überprüfen, ob die Umwandlung erfolgreich war
#       5 print(df.dtypes)
#
# File /opt/jupyterhub/lib/python3.11/site-packages/pandas/core/tools/datetimes.py:1067, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1065         result = arg.map(cache_array)
#    1066     else:
# -> 1067         values = convert_listlike(arg._values, format)
#    1068         result = arg._constructor(values, index=arg.index, name=arg.name)
#    1069 elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
#
# ...
